# %% [markdown]
# # Python facade
#
# Using Python as a scripting language can be highly convenient for developing scripts and integrating our analysis into other processes. However, learning a framework as complex as **flamapy** can initially seem overwhelming. To alleviate this, flamapy provides a straightforward method for executing the most common operations in Python.

# %% [markdown]
# ## Setup
#
# Install the distribution

# %%
# !pip install flamapy

# %% [markdown]
# Download sample UVL and configuration

# %%
# !wget -q "https://raw.githubusercontent.com/flamapy/flamapy/main/resources/models/simple/valid_model.uvl" -O "samplemodel.uvl"
# !wget -q "https://raw.githubusercontent.com/flamapy/flamapy/main/resources/configurations/valid_configuration.csvconf" -O "sampleconfiguration.csvconf"

# %% [markdown]
# Show sample model

# %%
# !cat "./samplemodel.uvl"
# Out:
# features
#     eCommerce { abstract }
#         mandatory
#             Server { abstract }
#                 mandatory
#                     PHP
#                         mandatory
#                             v74
#                     Storage
#                         alternative
#                             LOW
#                             ENOUGH
#             Web { abstract }
#                 mandatory
#                     Catalog
#                     Search
#                         alternative
#                             BASIC
#                             ADVANCED
#                     Shopping
#                         mandatory
#                             Cart
#                             Payment
#                                 or
#                                     PayPal
#                                     CreditCard
#                                     Mobile
#                     Security
#                         alternative
# ...

# %% [markdown]
# Show sample configuration

# %%
# !cat "sampleconfiguration.csvconf"
# Out:
# eCommerce,True
# Server,True
# PHP,True
# v74,True
# Storage,True
# LOW,True
# Web,True
# Catalog,True
# Search,True
# BASIC,True
# Shopping,True
# Cart,True
# Payment,True
# PayPal,True
# Security,True
# HIGH,True

# %% [markdown]
# ## Operations

# %% [markdown]
# Atomic Sets

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
result = fm.atomic_sets()
print(result)
# Out:
# [['Server', 'Catalog', 'Shopping', 'v74', 'Web', 'eCommerce', 'Cart', 'Payment', 'Security', 'Search', 'PHP', 'Storage'], ['LOW'], ['ENOUGH'], ['BASIC'], ['ADVANCED'], ['PayPal'], ['CreditCard'], ['Mobile'], ['HIGH'], ['STANDARD'], ['Backup'], ['Marketing'], ['SEO'], ['Socials'], ['Twitter'], ['Facebook'], ['YouTube']]

# %% [markdown]
# Average Branching Factor

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
avbf = fm.average_branching_factor()
print(avbf)
# Out:
# 2.45

# %% [markdown]
# Commonality

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
commonality = fm.commonality(("sampleconfiguration.csvconf"))
print(commonality)
# Out:
# 1.0

# %% [markdown]
# Configurations

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
configurations = fm.configurations()
print(configurations)
# Out:
# [Configuration({'eCommerce': True, 'Server': True, 'PHP': True, 'v74': True, 'Storage': True, 'ENOUGH': True, 'Web': True, 'Catalog': True, 'Search': True, 'ADVANCED': True, 'Shopping': True, 'Cart': True, 'Payment': True, 'Mobile': True, 'Security': True, 'HIGH': True}), Configuration({'Backup': True, 'eCommerce': True, 'Server': True, 'PHP': True, 'v74': True, 'Storage': True, 'ENOUGH': True, 'Web': True, 'Catalog': True, 'Search': True, 'ADVANCED': True, 'Shopping': True, 'Cart': True, 'Payment': True, 'Mobile': True, 'Security': True, 'HIGH': True}), Configuration({'eCommerce': True, 'Server': True, 'PHP': True, 'v74': True, 'Storage': True, 'ENOUGH': True, 'Web': True, 'Catalog': True, 'Search': True, 'ADVANCED': True, 'Shopping': True, 'Cart': True, 'Payment': True, 'Mobile': True, 'Security': True, 'HIGH': True, 'Marketing': True}), Configuration({'SEO': True, 'eCommerce': True, 'Server': True, 'PHP': True, 'v74': True, 'Storage': True, 'ENOUGH': True, 'Web': True, 'Catalog': 
# ...

# %% [markdown]
# Number of Configurations

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
configurations = fm.configurations_number()
print(configurations)
# Out:
# 816

# %% [markdown]
# Core Features

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
result = fm.core_features()
print(result)
# Out:
# ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'Web', 'Catalog', 'Search', 'Shopping', 'Cart', 'Payment', 'Security']

# %% [markdown]
# Count leafs

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.count_leafs()
print(operation)
# Out:
# 17

# %% [markdown]
# Dead Features

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
result = fm.dead_features()
print(result)
# Out:
# []

# %% [markdown]
# Estimated number of configurations

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.estimated_number_of_configurations()
print(operation)
# Out:
# 1904

# %% [markdown]
# False optional features

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
result = fm.false_optional_features()
print(result)
# Out:
# []

# %% [markdown]
# Feature ancestors

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.feature_ancestors("PHP")
print(operation)
# Out:
# ['Server', 'eCommerce']

# %% [markdown]
# Filter

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.filter(("sampleconfiguration.csvconf"))
print(operation)
# Out:
# [['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'Cart', 'Payment', 'PayPal', 'Security', 'HIGH'], ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'Cart', 'Payment', 'PayPal', 'Mobile', 'Security', 'HIGH'], ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'Cart', 'Payment', 'PayPal', 'Mobile', 'Security', 'HIGH', 'Marketing'], ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'Cart', 'Payment', 'PayPal', 'Mobile', 'Security', 'HIGH', 'Marketing', 'SEO'], ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'Cart', 'Payment', 'PayPal', 'Mobile', 'Security', 'HIGH', 'Marketing', 'SEO', 'Socials', 'Twitter'], ['eCommerce', 'Server', 'PHP', 'v74', 'Storage', 'LOW', 'Web', 'Catalog', 'Search', 'BASIC', 'Shopping', 'C
# ...

# %% [markdown]
# Leaf features

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.leaf_features()
print(operation)
# Out:
# ['v74', 'LOW', 'ENOUGH', 'Catalog', 'BASIC', 'ADVANCED', 'Cart', 'PayPal', 'CreditCard', 'Mobile', 'HIGH', 'STANDARD', 'Backup', 'SEO', 'Twitter', 'Facebook', 'YouTube']

# %% [markdown]
# Max depth

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.max_depth()
print(operation)
# Out:
# 4

# %% [markdown]
# Satisfiable

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
result = fm.satisfiable()
print(result)
# Out:
# True

# %% [markdown]
# Satisfiable configuration

# %%
from flamapy.interfaces.python.flamapy_feature_model import FLAMAFeatureModel
fm = FLAMAFeatureModel("./samplemodel.uvl")
operation = fm.satisfiable_configuration(("sampleconfiguration.csvconf"))
print(operation)
# Out:
# True
